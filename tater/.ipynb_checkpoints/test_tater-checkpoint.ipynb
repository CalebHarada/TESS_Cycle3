# %% [markdown]
# # Test TATER

# %%
import tater

# %%
tic_id = 43647325
transit_fitter = tater.TransitFitter(tic_id)

# %%
# You can change the MCMC settings as follows.
# transit_fitter.nwalkers = 15
# transit_fitter.nsteps = 3000
# transit_fitter.nburn = 1500

# %%
transit_fitter.download_data()
# Out:
#    retrieving stellar parameters...
# ------------------------------
#    TIC ID:	TIC 43647325
#    R_star:	1.09774 solRad
#    M_star:	1.135 solMass
#    logg:	4.41206
#    Teff:	6072.0
#    [Fe/H]:	-0.05
#    u1:	0.2590956040409782
#    u2:	0.29519228401192094
# ------------------------------
#    acquiring TESS data...
#    flattening light curve: 100%|██████████| 1/1 [00:00<00:00,  3.97it/s]
#    done.

# %%
TCEs = transit_fitter.find_planets()
# Out:
#   0%|          | 0/1827 periods | 00:00<?
# Transit Least Squares TLS 1.0.28 (13 June 2021)
# Creating model cache for 37 durations
# Searching 16239 data points, 1827 periods from 0.801 to 12.495 days
# Using all 4 CPU threads
# 100%|██████████| 1827/1827 periods | 00:15<00:00
#    TCE found at $P = 3.160318$ days with SDE of 28.151423
#
# [1, 3, 5, 7] [0, 2, 4, 6]
#   0%|          | 0/1827 periods | 00:00<?
# Transit Least Squares TLS 1.0.28 (13 June 2021)
# Creating model cache for 37 durations
# Searching 14602 data points, 1827 periods from 0.801 to 12.495 days
# Using all 4 CPU threads
# 100%|██████████| 1827/1827 periods | 00:09<00:00
#   6%|▌         | 343/5552 [00:00<00:01, 3426.71it/s]
# Searching for best T0 for period 2.35634 days
# 100%|██████████| 5552/5552 [00:01<00:00, 4260.15it/s]
#    checking previous signals: 100%|██████████| 1/1 [00:00<00:00, 5461.33it/s]
#    No additional TCEs found above SDE=10.0.
#
#    vetting TCEs...
#
#    vetting recovered 1 planet candidate(s) from 1 TCE(s).

# %%
transit_fitter.TCEs[0].oddeven_fig

# %%
transit_fitter.fit_transits()
# Out:
#   0%|          | 18/10000 [00:00<00:57, 172.36it/s]
#    Running MCMC for planet candidate with $P = 3.160318$ days (SDE=28.151423)
# 100%|██████████| 10000/10000 [00:52<00:00, 192.23it/s]
#    saving results...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-cb0190285918> in <module>
# ----> 1 transit_fitter.fit_transits()
#
# ~/Dropbox/My Mac (Caleb’s MacBook Pro)/Documents/UCBerkeley/Ongoing_Research/TESS_Cycle3/tater/tater.py in fit_transits(self, save_results)
#     226             if save_results:
#     227                 print("   saving results...")
# --> 228                 self._save_results_pdf_(candidate, i)
#     229                 print("   done.")
#     230
#
# ~/Dropbox/My Mac (Caleb’s MacBook Pro)/Documents/UCBerkeley/Ongoing_Research/TESS_Cycle3/tater/tater.py in _save_results_pdf_(self, planet_dict, planet_ind)
#     375
#     376         ttv_text_file = "{}/ttv_data_{}_0{}.txt".format(save_to_path, tic_no, planet_ind+1)
# --> 377         np.savetxt(ttv_text_file, planet_dict.ttv_data, comments="transit #, t0")
#     378
#     379         return None
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1380         if X.ndim == 0 or X.ndim > 2:
#    1381             raise ValueError(
# -> 1382                 "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1383         elif X.ndim == 1:
#    1384             # Common case -- 1d array of numbers
#
# ValueError: Expected 1D or 2D array, got 3D array instead

# %%
transit_fitter.TCEs[0].ttv_data
# Out:
# array([[[0.00000000e+00],
#         [1.44012272e+03]],
#
#        [[1.00000000e+00],
#         [1.44328437e+03]],
#
#        [[2.00000000e+00],
#         [1.44644582e+03]],
#
#        [[3.00000000e+00],
#         [1.44960752e+03]],
#
#        [[4.00000000e+00],
#         [1.45276875e+03]],
#
#        [[5.00000000e+00],
#         [1.45593072e+03]],
#
#        [[6.00000000e+00],
#         [1.45909193e+03]],
#
#        [[7.00000000e+00],
#         [1.46225383e+03]]])

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y = np.array([321, 514, 54, 12, 25])

np.savetxt("asdf.txt", np.array((x, y)).T)

# %%
stop

# %%
transit_fitter.TCEs[0].per_transit_count

# %%
transit_fitter.planet_candidates[0].per_transit_count

# %%
transit_fitter.planet_candidates[0].depth

# %%
transit_fitter.planet_candidates[0].depth_mean

# %%
transit_fitter.planet_candidates[0].depth_mean_even

# %%
transit_fitter.planet_candidates[0].depth_mean_odd

# %%
import numpy as np

# %%
from scipy.stats import linregress
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import batman

# %%
time = transit_fitter.time_raw
flux = transit_fitter.f_raw

# %%
def _model_single_transit_(t, t0, per, rp, a):

    params = batman.TransitParams()
    params.t0 = t0                       # time of inferior conjunction
    params.per = per                     # orbital period
    params.rp = rp                       # planet radius (in units of stellar radii)
    params.a = a                         # semi-major axis (in units of stellar radii)
    params.inc = 90.                     # orbital inclination (in degrees)
    params.ecc = 0.                      # eccentricity
    params.w = 90.                       # longitude of periastron (in degrees)
    params.u = [0.4, 0.4]                # limb darkening coefficients []
    params.limb_dark = "quadratic"       # limb darkening model

    model = batman.TransitModel(params, t)    # initializes model
    lc = model.light_curve(params)            # calculates light curve
    
    return lc

# %%
def _generate_vet_figures_(tce_dict):
    """Function to produce plot with vetting diagnostics"""
    
    # function to draw a line
    linear_func = lambda x, m, b: m*x + b

    # get useful info from dict
    transit_times = tce_dict.transit_times
    duration = tce_dict.duration
    period = tce_dict.period
    depth = tce_dict.depth
    
    # empty arrays
    t0_odd = []
    time_odd = []
    flux_odd = []
    depth_odd = []
    tfold_odd = []
    
    t0_even = []
    time_even = []
    flux_even = []
    depth_even = []
    tfold_even = []
    
    # treat each individual transit separately
    for i, t0 in enumerate(transit_times):
        
        # masks for ootr trend and in-transit
        transit_msk = (time > t0 - 3*duration) & (time < t0 + 3*duration)
        trend_msk = ((time > t0 - 3*duration) & (time < t0 - 1.5*duration)) | \
                    ((time < t0 + 3*duration) & (time > t0 + 1.5*duration))
        
        # fit line to ootr, normalize new flux
        slope, intercept, _, _, _ = linregress(time[trend_msk], flux[trend_msk])
        y_trend = linear_func(time[transit_msk], slope, intercept)
        time_new = time[transit_msk]
        f_new = flux[transit_msk] / y_trend
            
        # Fit transit model to each transit individually --> get t0, depths per transit
        p0 = [t0, np.sqrt(depth)]
        popt, _ = curve_fit(lambda t, t0_best, rp_best: _model_single_transit_(t,
                                                                               t0=t0_best,
                                                                               per=period,
                                                                               rp=rp_best,
                                                                               a=8.3), time_new, f_new, p0)
        # odd transits
        if i % 2:
            t0_odd.append(popt[0])
            time_odd.append(time_new)
            flux_odd.append(f_new)
            depth_odd.append(popt[1])
        
        # even transits
        else:
            t0_even.append(popt[0])
            time_even.append(time_new)
            flux_even.append(f_new)
            depth_even.append(popt[1])
    
    # make odd vs. even figure
    gridspec = dict(wspace=0.0, hspace=0.0, width_ratios=[1, 1])
    fig, axes = plt.subplots(1, 2, figsize=(10,6), sharey=True, gridspec_kw=gridspec)
    cmap = matplotlib.cm.get_cmap('inferno')
    
    # plot odd transits
    ax = axes[0]
    mean_depth_odd = np.mean(np.array(depth_odd)**2)
    std_depth_odd = np.std(np.array(depth_odd)**2)
    ax.axhline(1 - mean_depth_odd, c='b', ls='-', lw=2, alpha=0.2)
    ax.axhline(1 - (mean_depth_odd+std_depth_odd), c='b', ls='--', lw=1)
    ax.axhline(1 - (mean_depth_odd-std_depth_odd), c='b', ls='--', lw=1)
    ax.set_title("odd")
    ax.set_ylabel("relative flux")
    for i in range(len(time_odd)):
        color_values = np.linspace(0, 1, len(time_odd))
        t_fold = (time_odd[i] - t0_odd[i] + 0.5 * period) % period - 0.5 * period
        tfold_odd.append(t_fold)
        ax.scatter(t_fold*24, flux_odd[i], s=2, alpha=0.5, color=cmap(color_values[i]))
    tfold_odd = [item for sublist in tfold_odd for item in sublist]
    sort_ind = np.argsort(tfold_odd)
    
    #plot even transits
    ax = axes[1]
    mean_depth_even = np.mean(np.array(depth_even)**2)
    std_depth_even = np.std(np.array(depth_even)**2)
    ax.axhline(1 - mean_depth_even, c='b', ls='-', lw=2, alpha=0.2)
    ax.axhline(1 - (mean_depth_even+std_depth_even), c='b', ls='--', lw=1)
    ax.axhline(1 - (mean_depth_even-std_depth_even), c='b', ls='--', lw=1)
    ax.set_title("even")
    for i in range(len(time_even)):
        color_values = np.linspace(0, 1, len(time_even))
        t_fold = (time_even[i] - t0_even[i] + 0.5 * period) % period - 0.5 * period
        ax.scatter(t_fold*24, flux_even[i], s=2, alpha=0.5, color=cmap(color_values[i]))
    
    # format axes
    for ax in axes:
        ax.axhline(1.0, c='k', ls='--', lw=1, zorder=0)
        ax.set_xlabel("phase (hrs)")
    
    # make transit depth vs transit number figure
    transit_number = np.arange(len(t0_odd+t0_even))
    fig, ax = plt.subplots(1, 1, figsize=(8,6))
    ax.set_xlabel("transit number")
    ax.set_ylabel("transit depth")
    
    # plot each transit depth
    ax.axhline(1.0, c='k', ls='--')
    ax.plot(transit_number,
            [(1 - np.square(np.array(depth_odd+depth_even)))[i] for i in np.argsort(t0_odd+t0_even)],
            "kx", ms=12, zorder=10)
    
    # plot average trasnit depth
    mean_depth = np.mean(np.array(depth_odd+depth_even)**2)
    std_depth = np.std(np.array(depth_odd+depth_even)**2)
    ax.axhline(1 - mean_depth, c='b', ls='-', lw=2, alpha=0.2)
    ax.axhline(1 - (mean_depth+std_depth), c='b', ls='--', lw=1)
    ax.axhline(1 - (mean_depth-std_depth), c='b', ls='--', lw=1)
    
    
    # make transit TTV figure
    gridspec = dict(wspace=0.0, hspace=0.0, height_ratios=[1, 1])
    fig, axes = plt.subplots(2, 1, figsize=(10,8), sharex=True, gridspec_kw=gridspec)
    
    # plot transit center time vs. transit number
    ax = axes[0]
    ax.set_ylabel("transit center (d)")
    ax.plot(transit_number, np.sort(t0_odd+t0_even), "kx", ms=12)
    slope, intercept, _, _, _ = linregress(transit_number, np.sort(t0_odd+t0_even))
    y_fit = linear_func(transit_number, slope, intercept)
    ax.plot(transit_number, y_fit, 'b-')
    ax.text(0, np.sort(t0_odd+t0_even)[-2], " $P$ = {:.5f} d \n $T_0$ = {:.5f} d".format(slope, intercept))
    
    # plot residuals
    ax = axes[1]
    ax.set_xlabel("transit number")
    ax.set_ylabel("residuals (d)")
    ax.axhline(0.0, c='b', ls='--', lw=1, zorder=0)
    ax.plot(transit_number, np.sort(t0_odd+t0_even) - y_fit, "kx", ms=12)
    
    
    return depth_odd

# %%
_generate_vet_figures_(TCEs[0]);

# ADD TEXT ANNOTATIONS WITH ODD/EVEN DEPTHS, ETC
